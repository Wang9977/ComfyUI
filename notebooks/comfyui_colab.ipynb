# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %%
#@title Environment Setup

from pathlib import Path

OPTIONS = {}

USE_GOOGLE_DRIVE = False  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
WORKSPACE = 'ComfyUI'
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /
    print(212)
    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-
  # !git pull

# !echo -= Install dependencies =-
# !pip install xformers!=0.0.18 -r requirements.txt --extra-index-url https://download.pytorch.org/whl/cu121 --extra-index-url https://download.pytorch.org/whl/cu118 --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# /Users/wangyuan198/Documents/study/ml-in-fe/ComfyUI/notebooks/ComfyUI
# zsh:1: - not found
# Already up to date.
# zsh:1: - not found
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121, https://download.pytorch.org/whl/cu118, https://download.pytorch.org/whl/cu117
# Collecting xformers!=0.0.18
#   Downloading xformers-0.0.26.post1.tar.gz (4.1 MB)
#      |████████████████████████████████| 4.1 MB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: torch in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Collecting torchsde
#   Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: torchvision in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (0.17.2)
# Collecting torchaudio
#   Downloading torchaudio-2.2.2-cp38-cp38-macosx_10_13_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 1.4 MB/s eta 0:00:01
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 3.4 MB/s eta 0:00:01
# Collecting transformers>=4.25.1
#   Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 2.0 MB/s eta 0:00:01
# Collecting safetensors>=0.4.2
#   Downloading safetensors-0.4.3-cp38-cp38-macosx_10_12_x86_64.whl (416 kB)
#      |████████████████████████████████| 416 kB 3.1 MB/s eta 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.9.5-cp38-cp38-macosx_10_9_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (5.4.1)
# Requirement already satisfied: Pillow in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (8.2.0)
# Requirement already satisfied: scipy in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.6.2)
# Requirement already satisfied: tqdm in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (4.66.4)
# Requirement already satisfied: psutil in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (5.8.0)
# Collecting kornia>=0.7.1
#   Downloading kornia-0.7.2-py2.py3-none-any.whl (825 kB)
#      |████████████████████████████████| 825 kB 5.5 MB/s eta 0:00:01
# Collecting spandrel
#   Downloading spandrel-0.3.4-py3-none-any.whl (268 kB)
#      |████████████████████████████████| 268 kB 10.7 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from kornia>=0.7.1->-r requirements.txt (line 16)) (24.0)
# Collecting kornia-rs>=0.1.0
#   Downloading kornia_rs-0.1.3-cp38-cp38-macosx_10_12_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.0 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from torch->-r requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: fsspec in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from torch->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: sympy in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from torch->-r requirements.txt (line 1)) (1.8)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from torch->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: filelock in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from torch->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: networkx in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from torch->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: numpy>=1.17 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from transformers>=4.25.1->-r requirements.txt (line 6)) (1.19.5)
# Requirement already satisfied: requests in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from transformers>=4.25.1->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from transformers>=4.25.1->-r requirements.txt (line 6)) (2021.4.4)
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp38-cp38-macosx_10_12_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 212 kB/s eta 0:00:01
# Collecting huggingface-hub<1.0,>=0.23.0
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#      |████████████████████████████████| 402 kB 4.7 MB/s eta 0:00:01
# Collecting fsspec
#   Downloading fsspec-2024.6.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 4.7 MB/s eta 0:00:01
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.4-cp38-cp38-macosx_10_9_x86_64.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.5 MB/s eta 0:00:011
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp38-cp38-macosx_10_9_x86_64.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.9 MB/s eta 0:00:011
# Requirement already satisfied: attrs>=17.3.0 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from aiohttp->-r requirements.txt (line 8)) (20.3.0)
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.5-cp38-cp38-macosx_10_9_x86_64.whl (30 kB)
# Requirement already satisfied: idna>=2.0 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->-r requirements.txt (line 8)) (2.10)
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from jinja2->torch->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from networkx->torch->-r requirements.txt (line 1)) (5.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 6)) (2020.12.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.25.1->-r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: mpmath>=0.19 in /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages (from sympy->torch->-r requirements.txt (line 1)) (1.2.1)
# Building wheels for collected packages: xformers
#   Building wheel for xformers (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/wangyuan198/Downloads/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-install-_xhw2nhg/xformers_ef532bfc5d2142689d1bb018adfdbfb7/setup.py'"'"'; __file__='"'"'/private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-install-_xhw2nhg/xformers_ef532bfc5d2142689d1bb018adfdbfb7/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-wheel-zwdly8mn
#        cwd: /private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-install-_xhw2nhg/xformers_ef532bfc5d2142689d1bb018adfdbfb7/
#   Complete output (516 lines):
#   running bdist_wheel
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/utils/cpp_extension.py:500: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#     warnings.warn(msg.format('we could not find ninja.'))
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.8
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/_deprecation_warning.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/attn_bias_utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/checkpoint.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/test.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/_cpp_lib.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   copying xformers/info.py -> build/lib.macosx-10.9-x86_64-3.8/xformers
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/fused_linear_layer.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/vararg_kernel.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/k_activations.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/k_layer_norm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/k_fused_matmul_fw.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/dropout.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/k_dropout.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/softmax.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/layer_norm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/k_fused_matmul_bw.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   copying xformers/triton/k_softmax.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/triton
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/simplicial_embedding.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/residual.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/reversible.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/activations.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/multi_head_dispatch.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/input_projection.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   copying xformers/components/patch_embedding.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_mem_eff_attention.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_indexing.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_mlp.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_blocksparse_transformers.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_transformer.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_revnet.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_swiglu.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_triton_layernorm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_causal_blocksparse.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_triton_fused_linear.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_tiled_matmul.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_triton_blocksparse.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_triton_softmax.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_triton_dropout.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_nystrom_utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_attn_decoding.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_multi_head_dispatch.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_sequence_parallel_fused.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_sddmm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_sp24.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   copying xformers/benchmarks/benchmark_core.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/rmsnorm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/modpar_layers.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/swiglu_op.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/unbind.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/rope_padded.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/seqpar.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/ipc.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/sequence_parallel_fused_ops.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/sp24.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/common.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/differentiable_collectives.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/tiled_matmul.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   copying xformers/ops/indexing.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/device_limits.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/profiler_dcgm_impl.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/profiler_dcgm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/api.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/slow_ops_profiler.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   copying xformers/profiler/profiler.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/profiler
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/sparse
#   copying xformers/sparse/_csr_ops.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/sparse
#   copying xformers/sparse/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/sparse
#   copying xformers/sparse/utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/sparse
#   copying xformers/sparse/blocksparse_tensor.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/sparse
#   copying xformers/sparse/csr_tensor.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/sparse
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/helpers
#   copying xformers/helpers/test_utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/helpers
#   copying xformers/helpers/hierarchical_configs.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/helpers
#   copying xformers/helpers/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/helpers
#   copying xformers/helpers/timm_sparse_attention.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/helpers
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/fused_softmax.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/flash_blocksparse_attn_interface.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/flash_blocksparse_attention.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/bert_padding.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/flash_attn_triton_og.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/flash_attn_triton.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   copying xformers/_flash_attn/flash_attn_interface.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   copying xformers/factory/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   copying xformers/factory/hydra_helper.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   copying xformers/factory/block_factory.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   copying xformers/factory/model_factory.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   copying xformers/factory/block_configs.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   copying xformers/factory/weight_init.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/factory
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/global_tokens.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/ortho.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/blocksparse.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/local.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/compositional.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/pooling.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/_sputnik_sparse.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/core.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/lambda_layer.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/random.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/fourier_mix.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/scaled_dot_product.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/utils.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/attention_mask.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/linformer.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/attention_patterns.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/visual.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/sparsity_config.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/nystrom.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/favor.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   copying xformers/components/attention/base.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   copying xformers/components/feedforward/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   copying xformers/components/feedforward/mixture_of_experts.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   copying xformers/components/feedforward/mlp.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   copying xformers/components/feedforward/conv_mlp.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   copying xformers/components/feedforward/fused_mlp.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   copying xformers/components/feedforward/base.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/feedforward
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   copying xformers/components/positional_embedding/vocab.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   copying xformers/components/positional_embedding/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   copying xformers/components/positional_embedding/param.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   copying xformers/components/positional_embedding/sine.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   copying xformers/components/positional_embedding/rotary.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   copying xformers/components/positional_embedding/base.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/positional_embedding
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention/feature_maps
#   copying xformers/components/attention/feature_maps/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention/feature_maps
#   copying xformers/components/attention/feature_maps/softmax.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention/feature_maps
#   copying xformers/components/attention/feature_maps/base.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/components/attention/feature_maps
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   copying xformers/benchmarks/LRA/batch_submit.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   copying xformers/benchmarks/LRA/batch_fetch_results.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   copying xformers/benchmarks/LRA/run_with_submitit.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   copying xformers/benchmarks/LRA/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   copying xformers/benchmarks/LRA/run_tasks.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   copying xformers/benchmarks/LRA/run_grid_search.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA/code
#   copying xformers/benchmarks/LRA/code/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA/code
#   copying xformers/benchmarks/LRA/code/model_wrapper.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA/code
#   copying xformers/benchmarks/LRA/code/dataset.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/benchmarks/LRA/code
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/k_scaled_index_add.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/rope_padded_kernels.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/sequence_parallel_fused_kernels.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/tiled_matmul_kernels.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/k_index_select_cat.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   copying xformers/ops/_triton/rmsnorm_kernels.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/_triton
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/decoder.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/dispatch.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/attn_bias.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/ck.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/common.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/ck_decoder.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/flash.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/small_k.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/cutlass.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/ck_splitk.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   copying xformers/ops/fmha/triton_splitk.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/ops/fmha
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/losses
#   copying xformers/_flash_attn/losses/cross_entropy.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/losses
#   copying xformers/_flash_attn/losses/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/losses
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/layers
#   copying xformers/_flash_attn/layers/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/layers
#   copying xformers/_flash_attn/layers/patch_embed.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/layers
#   copying xformers/_flash_attn/layers/rotary.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/layers
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/utils
#   copying xformers/_flash_attn/utils/pretrained.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/utils
#   copying xformers/_flash_attn/utils/generation.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/utils
#   copying xformers/_flash_attn/utils/benchmark.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/utils
#   copying xformers/_flash_attn/utils/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/utils
#   copying xformers/_flash_attn/utils/distributed.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/utils
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/bigcode.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/gptj.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/opt.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/llama.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/vit.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/btlm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/baichuan.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/bert.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/falcon.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/gpt_neox.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   copying xformers/_flash_attn/models/gpt.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/models
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops
#   copying xformers/_flash_attn/ops/activations.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops
#   copying xformers/_flash_attn/ops/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops
#   copying xformers/_flash_attn/ops/fused_dense.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops
#   copying xformers/_flash_attn/ops/rms_norm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops
#   copying xformers/_flash_attn/ops/layer_norm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/modules
#   copying xformers/_flash_attn/modules/embedding.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/modules
#   copying xformers/_flash_attn/modules/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/modules
#   copying xformers/_flash_attn/modules/mlp.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/modules
#   copying xformers/_flash_attn/modules/block.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/modules
#   copying xformers/_flash_attn/modules/mha.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/modules
#   creating build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/cross_entropy.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/linear.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/k_activations.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/mlp.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/rotary.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   copying xformers/_flash_attn/ops/triton/layer_norm.py -> build/lib.macosx-10.9-x86_64-3.8/xformers/_flash_attn/ops/triton
#   running build_ext
#   building 'xformers._C' extension
#   creating build/temp.macosx-10.9-x86_64-3.8
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/attention
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/attention/autograd
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/attention/cpu
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/sequence_parallel_fused
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/sparse24
#   creating build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/swiglu
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/wangyuan198/Downloads/anaconda3/include -arch x86_64 -I/Users/wangyuan198/Downloads/anaconda3/include -arch x86_64 -I/private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-install-_xhw2nhg/xformers_ef532bfc5d2142689d1bb018adfdbfb7/xformers/csrc -I/Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include -I/Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include -I/Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/TH -I/Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/THC -I/Users/wangyuan198/Downloads/anaconda3/include/python3.8 -c xformers/csrc/attention/attention.cpp -o build/temp.macosx-10.9-x86_64-3.8/xformers/csrc/attention/attention.o -O3 -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_clang" -DPYBIND11_STDLIB="_libcpp" -DPYBIND11_BUILD_ABI="_cxxabi1002" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:7:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/Context.h:6:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/DeprecatedTypeProperties.h:110:34: error: 'value' is unavailable: introduced in macOS 10.13
#         Device device = device_opt.value();
#                                    ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type& value() &
#                             ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:28:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/util/OptionalArrayRef.h:159:34: error: 'value' is unavailable: introduced in macOS 10.13
#       return wrapped_opt_array_ref.value();
#                                    ^
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/util/OptionalArrayRef.h:222:13: note: in instantiation of member function 'c10::OptionalArrayRef<long long>::value' requested here
#     return a1.value() == other;
#               ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1057:33: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type const& value() const&
#                                   ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:31:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/CheckMemoryFormat.h:11:35: error: 'value' is unavailable: introduced in macOS 10.13
#         options.requires_grad_opt().value() == false,
#                                     ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1075:28: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type&& value() &&
#                              ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:4:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:442:26: error: 'value' is unavailable: introduced in macOS 10.13
#         TORCH_CHECK(inputs.value().size() > 0, "'inputs' argument to backward cannot be empty")
#                            ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type& value() &
#                             ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:4:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:443:30: error: 'value' is unavailable: introduced in macOS 10.13
#         this->_backward(inputs.value(), gradient, retain_graph, create_graph);
#                                ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type& value() &
#                             ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:28:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/util/OptionalArrayRef.h:131:34: error: 'value' is unavailable: introduced in macOS 10.13
#       return wrapped_opt_array_ref.value();
#                                    ^
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:5606:152: note: in instantiation of member function 'c10::OptionalArrayRef<long long>::operator*' requested here
#       return at::_ops::to_padded_tensor::call(const_cast<Tensor&>(*this), padding, output_size.has_value() ? c10::make_optional(c10::fromIntArrayRefSlow(*output_size)) : c10::nullopt);
#                                                                                                                                                          ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type& value() &
#                             ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:1551:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue_inl.h:12:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/jit_type.h:662:24: error: 'value' is unavailable: introduced in macOS 10.13
#         prod *= shape[i].value();
#                          ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1057:33: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type const& value() const&
#                                   ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:1551:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue_inl.h:12:
#   /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/jit_type.h:1512:28: error: 'value' is unavailable: introduced in macOS 10.13
#       const auto& n = name().value();
#                              ^
#   /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1057:33: note: 'value' has been explicitly marked unavailable here
#       constexpr value_type const& value() const&
#                                   ^
#   In file included from xformers/csrc/attention/attention.cpp:8:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#   In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
# ...
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:1551:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue_inl.h:12:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/jit_type.h:2129:20: error: 'value' is unavailable: introduced in macOS 10.13
#         return reason_.value();
#                        ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1057:33: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type const& value() const&
#                                     ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:1551:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue_inl.h:16:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/core/DeviceGuard.h:3:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/core/impl/InlineDeviceGuard.h:230:33: error: 'value' is unavailable: introduced in macOS 10.13
#           guard_.emplace(device_opt.value());
#                                     ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type& value() &
#                               ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:1551:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue_inl.h:16:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/core/DeviceGuard.h:3:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/core/impl/InlineDeviceGuard.h:242:39: error: 'value' is unavailable: introduced in macOS 10.13
#           guard_.emplace(device_index_opt.value());
#                                           ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type& value() &
#                               ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:1551:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue_inl.h:20:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/core/StreamGuard.h:3:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/core/impl/InlineStreamGuard.h:146:33: error: 'value' is unavailable: introduced in macOS 10.13
#           guard_.emplace(stream_opt.value());
#                                     ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type& value() &
#                               ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:27:38: error: 'value' is unavailable: introduced in macOS 10.13
#       return t.has_value() ? device_of(t.value()) : c10::nullopt;
#                                          ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1057:33: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type const& value() const&
#                                     ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:18:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/TensorIndexing.h:13:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/NativeFunctions.h:37:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ops/_addmm_activation_native.h:15:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ops/_addmm_activation_meta.h:12:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/TensorIterator.h:311:34: error: 'value' is unavailable: introduced in macOS 10.13
#         return operands_[arg].device.value();
#                                      ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1057:33: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type const& value() const&
#                                     ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:18:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/TensorIndexing.h:48:37: error: 'value' is unavailable: introduced in macOS 10.13
#           step_ = std::move(step_index).value();
#                                         ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1075:28: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type&& value() &&
#                                ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:18:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/TensorIndexing.h:56:39: error: 'value' is unavailable: introduced in macOS 10.13
#           start_ = std::move(start_index).value();
#                                           ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1075:28: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type&& value() &&
#                                ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:18:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/TensorIndexing.h:62:37: error: 'value' is unavailable: introduced in macOS 10.13
#           stop_ = std::move(stop_index).value();
#                                         ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1075:28: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type&& value() &&
#                                ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:18:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/TensorIndexing.h:243:25: error: 'value' is unavailable: introduced in macOS 10.13
#               !(maybe_index.value() == 0 && dim == 0 && self_sizes->empty()),
#                             ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type& value() &
#                               ^
#     In file included from xformers/csrc/attention/attention.cpp:8:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/ATen.h:9:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/DeviceGuard.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef.h:631:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/IListRef_inl.h:3:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List.h:490:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/List_inl.h:4:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/ivalue.h:4:
#     In file included from /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/core/TensorBody.h:28:
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/c10/util/OptionalArrayRef.h:155:34: error: 'value' is unavailable: introduced in macOS 10.13
#         return wrapped_opt_array_ref.value();
#                                      ^
#     /Users/wangyuan198/Downloads/anaconda3/lib/python3.8/site-packages/torch/include/ATen/WrapDimUtilsMulti.h:26:26: note: in instantiation of member function 'c10::OptionalArrayRef<long long>::value' requested here
#         auto dims = opt_dims.value();
#                              ^
#     /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/optional:1066:27: note: 'value' has been explicitly marked unavailable here
#         constexpr value_type& value() &
#                               ^
#     fatal error: too many errors emitted, stopping now [-ferror-limit=]
#     20 errors generated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/wangyuan198/Downloads/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-install-_xhw2nhg/xformers_ef532bfc5d2142689d1bb018adfdbfb7/setup.py'"'"'; __file__='"'"'/private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-install-_xhw2nhg/xformers_ef532bfc5d2142689d1bb018adfdbfb7/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/zx/q30vp6vx06s5gm1x6hmh8ft40000gp/T/pip-record-f0g6a5n0/install-record.txt --single-version-externally-managed --compile --install-headers /Users/wangyuan198/Downloads/anaconda3/include/python3.8/xformers Check the logs for full command output.

# %%
# !git clone https://github.com/comfyanonymous/ComfyUI
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 11377, done.
# remote: Counting objects: 100% (399/399), done.
# remote: Compressing objects: 100% (276/276), done.
# remote: Total 11377 (delta 236), reused 185 (delta 118), pack-reused 10978
# Receiving objects: 100% (11377/11377), 5.15 MiB | 2.00 MiB/s, done.
# Resolving deltas: 100% (7658/7658), done.

# %% [markdown]
# Download some models/checkpoints/vae or custom comfyui nodes (uncomment the commands for the ones you want)

# %%
# Checkpoints

### SDXL
### I recommend these workflow examples: https://comfyanonymous.github.io/ComfyUI_examples/sdxl/

#!wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors -P ./models/checkpoints/
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0.safetensors -P ./models/checkpoints/

# SDXL ReVision
#!wget -c https://huggingface.co/comfyanonymous/clip_vision_g/resolve/main/clip_vision_g.safetensors -P ./models/clip_vision/

# SD1.5
# !wget -c https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -P ./models/checkpoints/

# SD2
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.safetensors -P ./models/checkpoints/
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors -P ./models/checkpoints/

# Some SD1.5 anime style
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors -P ./models/checkpoints/
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A1_orangemixs.safetensors -P ./models/checkpoints/
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A3_orangemixs.safetensors -P ./models/checkpoints/
#!wget -c https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp16-pruned.safetensors -P ./models/checkpoints/

# Waifu Diffusion 1.5 (anime style SD2.x 768-v)
#!wget -c https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-illusion-fp16.safetensors -P ./models/checkpoints/


# unCLIP models
#!wget -c https://huggingface.co/comfyanonymous/illuminatiDiffusionV1_v11_unCLIP/resolve/main/illuminatiDiffusionV1_v11-unclip-h-fp16.safetensors -P ./models/checkpoints/
#!wget -c https://huggingface.co/comfyanonymous/wd-1.5-beta2_unCLIP/resolve/main/wd-1-5-beta2-aesthetic-unclip-h-fp16.safetensors -P ./models/checkpoints/


# VAE
# !wget -c https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -P ./models/vae/
#!wget -c https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt -P ./models/vae/
#!wget -c https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt -P ./models/vae/


# Loras
#!wget -c https://civitai.com/api/download/models/10350 -O ./models/loras/theovercomer8sContrastFix_sd21768.safetensors #theovercomer8sContrastFix SD2.x 768-v
#!wget -c https://civitai.com/api/download/models/10638 -O ./models/loras/theovercomer8sContrastFix_sd15.safetensors #theovercomer8sContrastFix SD1.x
#!wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors -P ./models/loras/ #SDXL offset noise lora


# T2I-Adapter
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_depth_sd14v1.pth -P ./models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_seg_sd14v1.pth -P ./models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_sketch_sd14v1.pth -P ./models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_keypose_sd14v1.pth -P ./models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_openpose_sd14v1.pth -P ./models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_color_sd14v1.pth -P ./models/controlnet/
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_canny_sd14v1.pth -P ./models/controlnet/

# T2I Styles Model
#!wget -c https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_style_sd14v1.pth -P ./models/style_models/

# CLIPVision model (needed for styles model)
#!wget -c https://huggingface.co/openai/clip-vit-large-patch14/resolve/main/pytorch_model.bin -O ./models/clip_vision/clip_vit14.bin


# ControlNet
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_canny_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_seg_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11u_sd15_tile_fp16.safetensors -P ./models/controlnet/

# ControlNet SDXL
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-canny-rank256.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-depth-rank256.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-recolor-rank256.safetensors -P ./models/controlnet/
#!wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-sketch-rank256.safetensors -P ./models/controlnet/

# Controlnet Preprocessor nodes by Fannovel16
#!cd custom_nodes && git clone https://github.com/Fannovel16/comfy_controlnet_preprocessors; cd comfy_controlnet_preprocessors && python install.py


# GLIGEN
#!wget -c https://huggingface.co/comfyanonymous/GLIGEN_pruned_safetensors/resolve/main/gligen_sd14_textbox_pruned_fp16.safetensors -P ./models/gligen/


# ESRGAN upscale model
#!wget -c https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P ./models/upscale_models/
#!wget -c https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x2.pth -P ./models/upscale_models/
#!wget -c https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x4.pth -P ./models/upscale_models/
# Out:
# zsh:1: command not found: wget
# zsh:1: command not found: wget

# %% [markdown]
# ### Run ComfyUI with cloudflared (Recommended Way)

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ### Run ComfyUI with localtunnel

# %%
# !npm install -g localtunnel

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  for line in p.stdout:
    print(line.decode(), end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ### Run ComfyUI with colab iframe (use only in case the previous way with localtunnel doesn't work)
#
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the link.
#
# Note that some UI features like live image previews won't work because the colab iframe blocks websockets.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
